# %%
#importing dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
requests.__version__
from config import weather_api_key
from datetime import datetime

# %%
# creating a list of 200 lats and longs 
lats = np.random.uniform(-90.000,90.000, size = 2000)
lngs = np.random.uniform(-180.000, 180.000, size = 2000)
lats_lngs = zip(lats,lngs)
lats_lngs

# %%
# making url 
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# adding lats_lngs zip to a list
coordinates = list(lats_lngs)
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

# %%
cities
# Out:
# ['ushuaia',
#  'kumo',
#  'camacha',
#  'cape town',
#  'tuktoyaktuk',
#  'tadine',
#  'colac',
#  'saskylakh',
#  'zaragoza',
#  'hermanus',
#  'rio grande',
#  'rikitea',
#  'alofi',
#  'punta arenas',
#  'maceio',
#  'norman wells',
#  'qaanaaq',
#  'lasa',
#  'cooma',
#  'carnarvon',
#  'bredasdorp',
#  'bambous virieux',
#  'sao joao da barra',
#  'sapao',
#  'belushya guba',
#  'babu',
#  'georgetown',
#  'jacmel',
#  'mataura',
#  'mayo',
#  'kapaa',
#  'barrow',
#  'vaini',
#  'provideniya',
#  'kavieng',
#  'teruel',
#  'port elizabeth',
#  'butaritari',
#  'cidreira',
#  'khatanga',
#  'kazalinsk',
#  'bengkulu',
#  'cherskiy',
#  'dikson',
#  'socorro',
#  'tasiilaq',
#  'muros',
#  'porosozero',
#  'busselton',
#  'selenginsk',
#  'taolanaro',
#  'abeche',
#  'bay roberts',
#  'hami',
#  'kasongo',
#  'port alfred',
#  'vila velha',
#  'ponta do sol',
#  'jamestown',
#  'tevaitoa',
#  'sao felix do xingu',
#  'puerto ayora',
#  'ballina',
#  'kushima',
#  'byron bay',
#  'albany',
#  'san patricio',
#  'avarua',
#  'hobart',
#  'half moon bay',
#  'luau',
#  'kathu',
#  'whitehorse',
#  'narsaq',
#  'ancud',
#  'longyearbyen',
#  'attawapiskat',
#  'pevek',
#  'inzer',
#  'vardo',
#  'yellowknife',
#  'oksfjord',
#  'chippewa falls',
#  'zyryanovsk',
#  'murgab',
#  'novoagansk',
#  'teya',
#  'sabang',
#  'illoqqortoormiut',
#  'beloha',
#  'klaksvik',
#  'yuzhno-yeniseyskiy',
#  'barentsburg',
#  'sorong',
#  'east london',
#  'emerald',
#  'lahaina',
#  'saleaula',
#  'sentyabrskiy',
#  'shingu',
#  'cabo san lucas',
#  'hithadhoo',
#  'pisco',
#  'stornoway',
#  'gao',
#  'inirida',
#  'yaan',
#  'adrar',
#  'caravelas',
#  'wexford',
#  'briancon',
#  'sabha',
#  'talawdi',
#  'wanning',
#  'la ronge',
#  'trollhattan',
#  'lufilufi',
#  'mineiros',
#  'bolungarvik',
#  'artyk',
#  'tastur',
#  'rawlins',
#  'castro',
#  'kununurra',
#  'quang ngai',
#  'matay',
#  'totma',
#  'tsihombe',
#  'atikokan',
#  'ulaangom',
#  'victoria',
#  'palabuhanratu',
#  'meulaboh',
#  'abaza',
#  'ardistan',
#  'saldanha',
#  'urdoma',
#  'nenjiang',
#  'te anau',
#  'luderitz',
#  'comodoro rivadavia',
#  'grand river south east',
#  'sakakah',
#  'scottsboro',
#  'mar del plata',
#  'ambilobe',
#  'new norfolk',
#  'oda',
#  'atuona',
#  'chuy',
#  'birao',
#  'kodiak',
#  'port hardy',
#  'kiruna',
#  'dharchula',
#  'sikonge',
#  'bluff',
#  'sosnovo-ozerskoye',
#  'hilo',
#  'tiksi',
#  'tsaratanana',
#  'kashi',
#  'nizhneyansk',
#  'tromso',
#  'chokurdakh',
#  'pierre',
#  'golspie',
#  'mount isa',
#  'amderma',
#  'saint-philippe',
#  'concordia',
#  'fairbanks',
#  'tongchuan',
#  'codrington',
#  'porto-vecchio',
#  'faanui',
#  'poum',
#  'moranbah',
#  'armacao dos buzios',
#  'burkhala',
#  'wageningen',
#  'alekseyevsk',
#  'quelimane',
#  'port hedland',
#  'ribeira grande',
#  'witham',
#  'leh',
#  'aklavik',
#  'yulara',
#  'bathsheba',
#  'erenhot',
#  'carutapera',
#  'lukaya',
#  'bethel',
#  'berdigestyakh',
#  'dolbeau',
#  'torbay',
#  'pacific grove',
#  'obo',
#  'afua',
#  'henties bay',
#  'lebu',
#  'coatepec harinas',
#  'sinegorye',
#  'dovolnoye',
#  'paita',
#  'ashland',
#  'qandala',
#  'kotelniki',
#  'mende',
#  'severo-kurilsk',
#  'thinadhoo',
#  'berlevag',
#  'batemans bay',
#  'srednekolymsk',
#  'zhuanghe',
#  'constitucion',
#  'taoudenni',
#  'kieta',
#  'antalaha',
#  'cap malheureux',
#  'zhigansk',
#  'ixtapa',
#  'trzcianka',
#  'ust-tsilma',
#  'yokadouma',
#  'clyde river',
#  'vizinga',
#  'virginia beach',
#  'hammerfest',
#  'pathein',
#  'port blair',
#  'kulhudhuffushi',
#  'kathmandu',
#  'praia',
#  'haines junction',
#  'balakhninskiy',
#  'poronaysk',
#  'arraial do cabo',
#  'souillac',
#  'muyezerskiy',
#  'vanavara',
#  'ialibu',
#  'esperance',
#  'sisimiut',
#  'ust-kut',
#  'maple creek',
#  'honiara',
#  'lulea',
#  'tual',
#  'saryshagan',
#  'hasaki',
#  'mecca',
#  'general pico',
#  'brooks',
#  'medvedka',
#  'airai',
#  'tomatlan',
#  'gubin',
#  'mapastepec',
#  'kokopo',
#  'san pedro',
#  'guerrero negro',
#  'wenceslau braz',
#  'kaka',
#  'kautokeino',
#  'lorengau',
#  'ouadda',
#  'ambodifototra',
#  'tabiauea',
#  'mahebourg',
#  'saint george',
#  'mudyuga',
#  'kahului',
#  'baykit',
#  'marawi',
#  'shimoda',
#  'muli',
#  'koslan',
#  'salalah',
#  'valdivia',
#  'katsuura',
#  'olga',
#  'sibu',
#  'svobodnyy',
#  'keshan',
#  'coahuayana',
#  'meinung',
#  'vidim',
#  'grindavik',
#  'asau',
#  'alta floresta',
#  'maracai',
#  'ostrovnoy',
#  'coquimbo',
#  'xocotla',
#  'aranos',
#  'umzimvubu',
#  'bullhead city',
#  'cayenne',
#  'otacilio costa',
#  'mlowo',
#  'evanton',
#  'barbar',
#  'luanda',
#  'port macquarie',
#  'maua',
#  'lagoa',
#  'kamenskoye',
#  'severo-yeniseyskiy',
#  'tigil',
#  'ko samui',
#  'seydi',
#  'derzhavinsk',
#  'san policarpo',
#  'kanchanaburi',
#  'zeya',
#  'saint-pierre',
#  'pangnirtung',
#  'formoso do araguaia',
#  'zmievka',
#  'guaruja',
#  'ewa beach',
#  'lovozero',
#  'clonakilty',
#  'umm bab',
#  'siyabuswa',
#  'sugito',
#  'port lincoln',
#  'chor',
#  'shakiso',
#  'tres arroyos',
#  'vaitupu',
#  'tuatapere',
#  'cockburn town',
#  'texarkana',
#  'tumannyy',
#  'nome',
#  'iqaluit',
#  'topi',
#  'kunming',
#  'tecoanapa',
#  'ahuimanu',
#  'fortuna',
#  'rio verde de mato grosso',
#  'isangel',
#  'lieksa',
#  'cintalapa',
#  'ambon',
#  'karauzyak',
#  'balgazyn',
#  'kutum',
#  'tambura',
#  'tooele',
#  'setaka',
#  'sonoita',
#  'grand gaube',
#  'khatassy',
#  'mamou',
#  'ponta delgada',
#  'vila franca do campo',
#  'tukums',
#  'zhanaozen',
#  'dondo',
#  'hay river',
#  'graciano sanchez',
#  'innisfail',
#  'khani',
#  'opuwo',
#  'mys shmidta',
#  'tucuman',
#  'svetlyy',
#  'roma',
#  'mama',
#  'ajdabiya',
#  'ossora',
#  'thompson',
#  'ayan',
#  'palauig',
#  'sao jose da coroa grande',
#  'burica',
#  'nagornyy',
#  'kenai',
#  'alice springs',
#  'sale',
#  'svetlaya',
#  'golden',
#  'mana',
#  'kalangala',
#  'kungurtug',
#  'uusikaupunki',
#  'touros',
#  'nokha',
#  'ocosingo',
#  'port moresby',
#  'tolaga bay',
#  'dali',
#  'egvekinot',
#  'zlitan',
#  'dunedin',
#  'mahanoro',
#  'vallenar',
#  'turayf',
#  'gamba',
#  'gambela',
#  'krasnoye',
#  'veraval',
#  'mahon',
#  'sitka',
#  'lavrentiya',
#  'lamu',
#  'kendari',
#  'machachi',
#  'bandarbeyla',
#  'upernavik',
#  'sechura',
#  'nikolskoye',
#  'geraldton',
#  'tyukhtet',
#  'chapleau',
#  'okhotsk',
#  'bar-le-duc',
#  'sao filipe',
#  'cabras',
#  'the valley',
#  'fayaoue',
#  'kaitangata',
#  'rudnya',
#  'alihe',
#  'marcona',
#  'waipawa',
#  'turukhansk',
#  'shelbyville',
#  'rawson',
#  'ilulissat',
#  'pandan',
#  'san juan',
#  'acapulco',
#  'marystown',
#  'sibolga',
#  'santa fe',
#  'nanortalik',
#  'yatou',
#  'brae',
#  'spokane',
#  'phangnga',
#  'khor',
#  'lompoc',
#  'bulungu',
#  'harper',
#  'shaunavon',
#  'sao miguel do araguaia',
#  'samalaeulu',
#  'waingapu',
#  'ondorhaan',
#  'verkhnevilyuysk',
#  'talas',
#  'taft',
#  'visby',
#  'naftah',
#  'gornopravdinsk',
#  'pentecoste',
#  'duldurga',
#  'lichtenburg',
#  'galle',
#  'aasiaat',
#  'yichun',
#  'ritchie',
#  'santo antonio do ica',
#  'zhuhai',
#  'el badari',
#  'delijan',
#  'sabla',
#  'mormugao',
#  'belaya gora',
#  'laguna',
#  'cordoba',
#  'gold coast',
#  'olafsvik',
#  'verkhnyaya inta',
#  'farafangana',
#  'chemal',
#  'port-cartier',
#  'aguimes',
#  'nuuk',
#  'lazaro cardenas',
#  'ulladulla',
#  'bryukhovetskaya',
#  'urk',
#  'pundaguitan',
#  'itarantim',
#  'toumodi',
#  'margate',
#  'padang',
#  'nador',
#  'flin flon',
#  'cadillac',
#  'teguise',
#  'beihai',
#  'sebaco',
#  'muzhi',
#  'marsabit',
#  'candido de abreu',
#  'le port',
#  'santa rosa',
#  'ostersund',
#  'feicheng',
#  'namatanai',
#  'vigrestad',
#  'garissa',
#  'aksarka',
#  'sioux lookout',
#  'leningradskiy',
#  'axim',
#  'krasnaya gorbatka',
#  'mayumba',
#  'jishou',
#  'chagda',
#  'yekaterinburg',
#  'makakilo city',
#  'praia da vitoria',
#  'kruisfontein',
#  'novaya igirma',
#  'vagamo',
#  'dingle',
#  'lillooet',
#  'plettenberg bay',
#  'college',
#  'taksimo',
#  'angoche',
#  'ellensburg',
#  'simao',
#  'constantine',
#  'sinkat',
#  'belluno',
#  'stekolnyy',
#  'fuerte olimpo',
#  'santa vitoria do palmar',
#  'borovskoy',
#  'samarai',
#  'hambantota',
#  'kjollefjord',
#  'riyadh',
#  'victor harbor',
#  'bayir',
#  'odessa',
#  'tiarei',
#  'bilma',
#  'umm durman',
#  'iskenderun',
#  'puerto quijarro',
#  'portland',
#  'coihaique',
#  'bingol',
#  'minnedosa',
#  'takoradi',
#  'mut',
#  'baihar',
#  'noumea',
#  'kegayli',
#  'luancheng',
#  'vila do maio',
#  'lagoa da prata',
#  'san ramon',
#  'pitimbu',
#  'pemba',
#  'babai',
#  'road town',
#  'eldikan',
#  'yar-sale',
#  'morelia',
#  'kijang',
#  'erzurum',
#  'ilebo',
#  'naberera',
#  'russell',
#  'tapaua',
#  'karratha',
#  'batken',
#  'taguatinga',
#  'red wing',
#  'ewo',
#  'komsomolskiy',
#  'bikin',
#  'cabra',
#  'pringsewu',
#  'lodja',
#  'poquoson',
#  'necochea',
#  'roald',
#  'ulcinj',
#  'biak',
#  'tahe',
#  'maniwaki',
#  'kavaratti',
#  'dongli',
#  'cardenas',
#  'anloga',
#  'tunduru',
#  'saint-georges',
#  'ardakan',
#  'adre',
#  'polis',
#  'burnie',
#  'gizo',
#  'agaro',
#  'thai binh',
#  'talnakh',
#  'gobabis',
#  'oranjemund',
#  'jiangyou',
#  'santo tomas',
#  'clinton',
#  'bargal',
#  'bud',
#  'kifri',
#  'laredo',
#  'breves',
#  'yicheng',
#  'haysville',
#  'vestmanna',
#  'aitape',
#  'morehead',
#  'ambanja',
#  'digby',
#  'namanga',
#  'coihueco',
#  'vao',
#  'cabedelo',
#  'choix',
#  'san giovanni lupatoto',
#  'payakumbuh',
#  'camana',
#  'yumen',
#  'hirara',
#  'tarudant',
#  'carinhanha',
#  'biggar',
#  'bucyrus',
#  'kamenka',
#  'santa maria',
#  'sevierville',
#  'mackay',
#  'ouesso',
#  'pacatuba',
#  'yanchukan',
#  'victoria point',
#  'tapejara',
#  'graaff-reinet',
#  'mmabatho',
#  'takaka',
#  'dzerzhinsk',
#  'bubaque',
#  'jiwani',
#  'gayny',
#  'ketchikan',
#  'mimongo',
#  'forio',
#  'tabas',
#  'fort nelson',
#  'mount gambier',
#  'hinton',
#  'santa lucia',
#  'torrevieja',
#  'vestmannaeyjar',
#  'hamilton',
#  'nyurba',
#  'milingimbi',
#  'samusu',
#  'juneau',
#  'namibe',
#  'fukue',
#  'abu samrah',
#  'haderslev',
#  'rocha',
#  'tarrega',
#  'lichinga',
#  'richards bay',
#  'milyutinskaya',
#  'havre-saint-pierre',
#  'sulangan',
#  'conceicao do araguaia',
#  'tyristrand',
#  'winnemucca',
#  'buala',
#  'tornio',
#  'bagdarin',
#  'harvard',
#  'batagay',
#  'tura',
#  'rafsanjan',
#  'datong',
#  'fujin',
#  'nong phai',
#  'skjervoy',
#  'cauquenes',
#  'klyuchi',
#  'lyuban',
#  'san jose',
#  'port pirie',
#  'tyup',
#  'mantua',
#  'guaira',
#  'ingham',
#  'upata',
#  'yaguajay',
#  'satitoa',
#  'ust-omchug',
#  'gunnaur',
#  'bay city',
#  'kearney',
#  'merauke',
#  'nishihara',
#  'mendi',
#  'abbeville',
#  'huilong',
#  'ahipara',
#  'pochutla',
#  'mrirt',
#  'tautira',
#  'atar',
#  'bambanglipuro',
#  'kantang',
#  'safety harbor',
#  'gemena',
#  'buraydah',
#  'sorvag',
#  'hurricane',
#  'moosomin',
#  'bowen',
#  'malkara',
#  'korla',
#  'conde',
#  'broken hill',
#  'tilichiki',
#  'haibowan',
#  'oyama',
#  'agirish',
#  'atyuryevo',
#  'samana',
#  'husavik',
#  'grimshaw',
#  'xichang',
#  'abha',
#  'okato',
#  'magadan',
#  'ionia',
#  'ilo',
#  'mazamari',
#  'huntsville',
#  'duma',
#  'inuvik',
#  'toliary',
#  'muisne',
#  'ileza',
#  'honningsvag',
#  'spring valley',
#  'ippy',
#  'raudeberg',
#  'galesong',
#  'banmo',
#  'kainantu',
#  'pombal',
#  'marabba',
#  'scunthorpe',
#  'vredendal',
#  'broome',
#  'serra talhada',
#  'great falls',
#  'choya',
#  'launceston',
#  'yelizovo',
#  'ranfurly',
#  'guamal',
#  'requena',
#  'sarangani',
#  'qaqortoq',
#  'tokur',
#  'koumac',
#  'woodward',
#  'yomitan',
#  'zhumadian',
#  'neiafu',
#  'monrovia',
#  'labuhan',
#  'cockburn harbour',
#  'watsa',
#  'ca mau',
#  'dzhusaly',
#  'paamiut',
#  'nemyriv',
#  'junin',
#  'bonavista',
#  'chingirlau',
#  'naryan-mar',
#  'tabou',
#  'kokoda']

# %%
# loop to get weather information
city_data = []
#printing begining of loop
print("Beginning Data Retrieval")
print("------------------------")
#creating counters
record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(city_url) 
    record_count += 1

    try:
        req = requests.get(city_url)
        city_weather = req.json()
        #data needed
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_cloud = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_data.append({"City" : city.title(),
                          "Country" : city_country,
                          "Lat" :  city_lat,
                          "Lng" : city_lng,
                          "Max Temp" : city_max_temp,
                          "Humidity" : city_humidity,
                          "Cloudiness" : city_cloud,
                          "Wind Speed" : city_wind,
                          "Current Description" : city_desc})
    except:
        print("City not found. Skipping...")
        pass
print("Done")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ushuaia
# Processing Record 2 of Set 1 | kumo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kumo
# Processing Record 3 of Set 1 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=camacha
# Processing Record 4 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=cape+town
# Processing Record 5 of Set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=tuktoyaktuk
# Processing Record 6 of Set 1 | tadine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=tadine
# Processing Record 7 of Set 1 | colac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=colac
# Processing Record 8 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=saskylakh
# Processing Record 9 of Set 1 | zaragoza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=zaragoza
# Processing Record 10 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=hermanus
# Processing Record 11 of Set 1 | rio grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=rio+grande
# Processing Record 12 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=rikitea
# Processing Record 13 of Set 1 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=alofi
# Processing Record 14 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=punta+arenas
# Processing Record 15 of Set 1 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=maceio
# Processing Record 16 of Set 1 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=norman+wells
# Processing Record 17 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=qaanaaq
# Processing Record 18 of Set 1 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=lasa
# Processing Record 19 of Set 1 | cooma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=cooma
# Processing Record 20 of Set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=carnarvon
# Processing Record 21 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=bredasdorp
# Processing Record 22 of Set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=bambous+virieux
# Processing Record 23 of Set 1 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=sao+joao+da+barra
# Processing Record 24 of Set 1 | sapao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=sapao
# City not found. Skipping...
# Processing Record 25 of Set 1 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=belushya+guba
# City not found. Skipping...
# Processing Record 26 of Set 1 | babu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=babu
# Processing Record 27 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=georgetown
# Processing Record 28 of Set 1 | jacmel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=jacmel
# Processing Record 29 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=mataura
# Processing Record 30 of Set 1 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=mayo
# Processing Record 31 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kapaa
# Processing Record 32 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=barrow
# Processing Record 33 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=vaini
# Processing Record 34 of Set 1 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=provideniya
# Processing Record 35 of Set 1 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kavieng
# Processing Record 36 of Set 1 | teruel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=teruel
# Processing Record 37 of Set 1 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=port+elizabeth
# Processing Record 38 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=butaritari
# Processing Record 39 of Set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=cidreira
# Processing Record 40 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=khatanga
# Processing Record 41 of Set 1 | kazalinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 1 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=bengkulu
# Processing Record 43 of Set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=cherskiy
# Processing Record 44 of Set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=dikson
# Processing Record 45 of Set 1 | socorro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=socorro
# Processing Record 46 of Set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=tasiilaq
# Processing Record 47 of Set 1 | muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=muros
# Processing Record 48 of Set 1 | porosozero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=porosozero
# Processing Record 49 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=busselton
# Processing Record 50 of Set 1 | selenginsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=selenginsk
# Processing Record 1 of Set 2 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 2 | abeche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=abeche
# Processing Record 3 of Set 2 | bay roberts
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=bay+roberts
# Processing Record 4 of Set 2 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=hami
# Processing Record 5 of Set 2 | kasongo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kasongo
# Processing Record 6 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=port+alfred
# Processing Record 7 of Set 2 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=vila+velha
# Processing Record 8 of Set 2 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ponta+do+sol
# Processing Record 9 of Set 2 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=jamestown
# Processing Record 10 of Set 2 | tevaitoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=tevaitoa
# Processing Record 11 of Set 2 | sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=sao+felix+do+xingu
# Processing Record 12 of Set 2 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=puerto+ayora
# Processing Record 13 of Set 2 | ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ballina
# Processing Record 14 of Set 2 | kushima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kushima
# Processing Record 15 of Set 2 | byron bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=byron+bay
# Processing Record 16 of Set 2 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=albany
# Processing Record 17 of Set 2 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=san+patricio
# Processing Record 18 of Set 2 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=avarua
# Processing Record 19 of Set 2 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=hobart
# Processing Record 20 of Set 2 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=half+moon+bay
# Processing Record 21 of Set 2 | luau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=luau
# Processing Record 22 of Set 2 | kathu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kathu
# Processing Record 23 of Set 2 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=whitehorse
# Processing Record 24 of Set 2 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=narsaq
# Processing Record 25 of Set 2 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ancud
# Processing Record 26 of Set 2 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=longyearbyen
# Processing Record 27 of Set 2 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 2 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=pevek
# Processing Record 29 of Set 2 | inzer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=inzer
# Processing Record 30 of Set 2 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=vardo
# Processing Record 31 of Set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=yellowknife
# Processing Record 32 of Set 2 | oksfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=oksfjord
# Processing Record 33 of Set 2 | chippewa falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=chippewa+falls
# Processing Record 34 of Set 2 | zyryanovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=zyryanovsk
# Processing Record 35 of Set 2 | murgab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=murgab
# Processing Record 36 of Set 2 | novoagansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=novoagansk
# Processing Record 37 of Set 2 | teya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=teya
# Processing Record 38 of Set 2 | sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=sabang
# Processing Record 39 of Set 2 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 2 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=beloha
# Processing Record 41 of Set 2 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=klaksvik
# Processing Record 42 of Set 2 | yuzhno-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 43 of Set 2 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 2 | sorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=sorong
# Processing Record 45 of Set 2 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=east+london
# Processing Record 46 of Set 2 | emerald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=emerald
# Processing Record 47 of Set 2 | lahaina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=lahaina
# Processing Record 48 of Set 2 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=saleaula
# City not found. Skipping...
# Processing Record 49 of Set 2 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 2 | shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=shingu
# Processing Record 1 of Set 3 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=cabo+san+lucas
# Processing Record 2 of Set 3 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=hithadhoo
# Processing Record 3 of Set 3 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=pisco
# Processing Record 4 of Set 3 | stornoway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=stornoway
# Processing Record 5 of Set 3 | gao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=gao
# Processing Record 6 of Set 3 | inirida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=inirida
# Processing Record 7 of Set 3 | yaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=yaan
# Processing Record 8 of Set 3 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=adrar
# Processing Record 9 of Set 3 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=caravelas
# Processing Record 10 of Set 3 | wexford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=wexford
# Processing Record 11 of Set 3 | briancon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=briancon
# Processing Record 12 of Set 3 | sabha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=sabha
# Processing Record 13 of Set 3 | talawdi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=talawdi
# City not found. Skipping...
# Processing Record 14 of Set 3 | wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=wanning
# Processing Record 15 of Set 3 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=la+ronge
# Processing Record 16 of Set 3 | trollhattan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=trollhattan
# Processing Record 17 of Set 3 | lufilufi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=lufilufi
# Processing Record 18 of Set 3 | mineiros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=mineiros
# Processing Record 19 of Set 3 | bolungarvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 3 | artyk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=artyk
# City not found. Skipping...
# Processing Record 21 of Set 3 | tastur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=tastur
# Processing Record 22 of Set 3 | rawlins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=rawlins
# Processing Record 23 of Set 3 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=castro
# Processing Record 24 of Set 3 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kununurra
# Processing Record 25 of Set 3 | quang ngai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=quang+ngai
# Processing Record 26 of Set 3 | matay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=matay
# Processing Record 27 of Set 3 | totma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=totma
# Processing Record 28 of Set 3 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 3 | atikokan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=atikokan
# Processing Record 30 of Set 3 | ulaangom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ulaangom
# Processing Record 31 of Set 3 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=victoria
# Processing Record 32 of Set 3 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 3 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=meulaboh
# Processing Record 34 of Set 3 | abaza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=abaza
# Processing Record 35 of Set 3 | ardistan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ardistan
# City not found. Skipping...
# Processing Record 36 of Set 3 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=saldanha
# Processing Record 37 of Set 3 | urdoma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=urdoma
# Processing Record 38 of Set 3 | nenjiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=nenjiang
# Processing Record 39 of Set 3 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=te+anau
# Processing Record 40 of Set 3 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=luderitz
# Processing Record 41 of Set 3 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=comodoro+rivadavia
# Processing Record 42 of Set 3 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=grand+river+south+east
# City not found. Skipping...
# Processing Record 43 of Set 3 | sakakah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=sakakah
# Processing Record 44 of Set 3 | scottsboro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=scottsboro
# Processing Record 45 of Set 3 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=mar+del+plata
# Processing Record 46 of Set 3 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ambilobe
# Processing Record 47 of Set 3 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=new+norfolk
# Processing Record 48 of Set 3 | oda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=oda
# Processing Record 49 of Set 3 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=atuona
# Processing Record 50 of Set 3 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=chuy
# Processing Record 1 of Set 4 | birao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=birao
# Processing Record 2 of Set 4 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kodiak
# Processing Record 3 of Set 4 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=port+hardy
# Processing Record 4 of Set 4 | kiruna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kiruna
# Processing Record 5 of Set 4 | dharchula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=dharchula
# Processing Record 6 of Set 4 | sikonge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=sikonge
# Processing Record 7 of Set 4 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=bluff
# Processing Record 8 of Set 4 | sosnovo-ozerskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=sosnovo-ozerskoye
# Processing Record 9 of Set 4 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=hilo
# Processing Record 10 of Set 4 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=tiksi
# Processing Record 11 of Set 4 | tsaratanana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=tsaratanana
# Processing Record 12 of Set 4 | kashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kashi
# Processing Record 13 of Set 4 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 4 | tromso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=tromso
# Processing Record 15 of Set 4 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=chokurdakh
# Processing Record 16 of Set 4 | pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=pierre
# Processing Record 17 of Set 4 | golspie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=golspie
# Processing Record 18 of Set 4 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=mount+isa
# Processing Record 19 of Set 4 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=amderma
# City not found. Skipping...
# Processing Record 20 of Set 4 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=saint-philippe
# Processing Record 21 of Set 4 | concordia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=concordia
# Processing Record 22 of Set 4 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=fairbanks
# Processing Record 23 of Set 4 | tongchuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=tongchuan
# Processing Record 24 of Set 4 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=codrington
# Processing Record 25 of Set 4 | porto-vecchio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=porto-vecchio
# Processing Record 26 of Set 4 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=faanui
# Processing Record 27 of Set 4 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=poum
# Processing Record 28 of Set 4 | moranbah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=moranbah
# Processing Record 29 of Set 4 | armacao dos buzios
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=armacao+dos+buzios
# City not found. Skipping...
# Processing Record 30 of Set 4 | burkhala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=burkhala
# City not found. Skipping...
# Processing Record 31 of Set 4 | wageningen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=wageningen
# Processing Record 32 of Set 4 | alekseyevsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=alekseyevsk
# Processing Record 33 of Set 4 | quelimane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=quelimane
# Processing Record 34 of Set 4 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=port+hedland
# Processing Record 35 of Set 4 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ribeira+grande
# Processing Record 36 of Set 4 | witham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=witham
# Processing Record 37 of Set 4 | leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=leh
# Processing Record 38 of Set 4 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=aklavik
# Processing Record 39 of Set 4 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=yulara
# Processing Record 40 of Set 4 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=bathsheba
# Processing Record 41 of Set 4 | erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=erenhot
# Processing Record 42 of Set 4 | carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=carutapera
# Processing Record 43 of Set 4 | lukaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=lukaya
# Processing Record 44 of Set 4 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=bethel
# Processing Record 45 of Set 4 | berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=berdigestyakh
# Processing Record 46 of Set 4 | dolbeau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=dolbeau
# City not found. Skipping...
# Processing Record 47 of Set 4 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=torbay
# Processing Record 48 of Set 4 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=pacific+grove
# Processing Record 49 of Set 4 | obo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=obo
# Processing Record 50 of Set 4 | afua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=afua
# Processing Record 1 of Set 5 | henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=henties+bay
# Processing Record 2 of Set 5 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=lebu
# Processing Record 3 of Set 5 | coatepec harinas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=coatepec+harinas
# Processing Record 4 of Set 5 | sinegorye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=sinegorye
# Processing Record 5 of Set 5 | dovolnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=dovolnoye
# Processing Record 6 of Set 5 | paita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=paita
# Processing Record 7 of Set 5 | ashland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ashland
# Processing Record 8 of Set 5 | qandala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=qandala
# Processing Record 9 of Set 5 | kotelniki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kotelniki
# Processing Record 10 of Set 5 | mende
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=mende
# Processing Record 11 of Set 5 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=severo-kurilsk
# Processing Record 12 of Set 5 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=thinadhoo
# Processing Record 13 of Set 5 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=berlevag
# Processing Record 14 of Set 5 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=batemans+bay
# Processing Record 15 of Set 5 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=srednekolymsk
# Processing Record 16 of Set 5 | zhuanghe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=zhuanghe
# Processing Record 17 of Set 5 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=constitucion
# Processing Record 18 of Set 5 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=taoudenni
# Processing Record 19 of Set 5 | kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kieta
# Processing Record 20 of Set 5 | antalaha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=antalaha
# Processing Record 21 of Set 5 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=cap+malheureux
# Processing Record 22 of Set 5 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=zhigansk
# Processing Record 23 of Set 5 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ixtapa
# Processing Record 24 of Set 5 | trzcianka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=trzcianka
# Processing Record 25 of Set 5 | ust-tsilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ust-tsilma
# Processing Record 26 of Set 5 | yokadouma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=yokadouma
# Processing Record 27 of Set 5 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=clyde+river
# Processing Record 28 of Set 5 | vizinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=vizinga
# Processing Record 29 of Set 5 | virginia beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=virginia+beach
# Processing Record 30 of Set 5 | hammerfest
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=hammerfest
# Processing Record 31 of Set 5 | pathein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=pathein
# Processing Record 32 of Set 5 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=port+blair
# Processing Record 33 of Set 5 | kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kulhudhuffushi
# Processing Record 34 of Set 5 | kathmandu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kathmandu
# Processing Record 35 of Set 5 | praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=praia
# Processing Record 36 of Set 5 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=haines+junction
# Processing Record 37 of Set 5 | balakhninskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=balakhninskiy
# Processing Record 38 of Set 5 | poronaysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=poronaysk
# Processing Record 39 of Set 5 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=arraial+do+cabo
# Processing Record 40 of Set 5 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=souillac
# Processing Record 41 of Set 5 | muyezerskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=muyezerskiy
# Processing Record 42 of Set 5 | vanavara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=vanavara
# Processing Record 43 of Set 5 | ialibu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ialibu
# Processing Record 44 of Set 5 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=esperance
# Processing Record 45 of Set 5 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=sisimiut
# Processing Record 46 of Set 5 | ust-kut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ust-kut
# Processing Record 47 of Set 5 | maple creek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=maple+creek
# Processing Record 48 of Set 5 | honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=honiara
# Processing Record 49 of Set 5 | lulea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=lulea
# Processing Record 50 of Set 5 | tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=tual
# Processing Record 1 of Set 6 | saryshagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=saryshagan
# City not found. Skipping...
# Processing Record 2 of Set 6 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=hasaki
# Processing Record 3 of Set 6 | mecca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=mecca
# Processing Record 4 of Set 6 | general pico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=general+pico
# Processing Record 5 of Set 6 | brooks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=brooks
# Processing Record 6 of Set 6 | medvedka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=medvedka
# Processing Record 7 of Set 6 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=airai
# Processing Record 8 of Set 6 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=tomatlan
# Processing Record 9 of Set 6 | gubin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=gubin
# Processing Record 10 of Set 6 | mapastepec
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=mapastepec
# Processing Record 11 of Set 6 | kokopo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kokopo
# Processing Record 12 of Set 6 | san pedro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=san+pedro
# Processing Record 13 of Set 6 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=guerrero+negro
# Processing Record 14 of Set 6 | wenceslau braz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=wenceslau+braz
# Processing Record 15 of Set 6 | kaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kaka
# Processing Record 16 of Set 6 | kautokeino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kautokeino
# Processing Record 17 of Set 6 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=lorengau
# Processing Record 18 of Set 6 | ouadda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ouadda
# Processing Record 19 of Set 6 | ambodifototra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ambodifototra
# City not found. Skipping...
# Processing Record 20 of Set 6 | tabiauea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 6 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=mahebourg
# Processing Record 22 of Set 6 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=saint+george
# Processing Record 23 of Set 6 | mudyuga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=mudyuga
# City not found. Skipping...
# Processing Record 24 of Set 6 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kahului
# Processing Record 25 of Set 6 | baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=baykit
# Processing Record 26 of Set 6 | marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=marawi
# Processing Record 27 of Set 6 | shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=shimoda
# Processing Record 28 of Set 6 | muli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=muli
# Processing Record 29 of Set 6 | koslan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=koslan
# Processing Record 30 of Set 6 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=salalah
# Processing Record 31 of Set 6 | valdivia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=valdivia
# Processing Record 32 of Set 6 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=katsuura
# Processing Record 33 of Set 6 | olga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=olga
# Processing Record 34 of Set 6 | sibu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=sibu
# Processing Record 35 of Set 6 | svobodnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=svobodnyy
# Processing Record 36 of Set 6 | keshan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=keshan
# City not found. Skipping...
# Processing Record 37 of Set 6 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=coahuayana
# Processing Record 38 of Set 6 | meinung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=meinung
# City not found. Skipping...
# Processing Record 39 of Set 6 | vidim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=vidim
# Processing Record 40 of Set 6 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=grindavik
# Processing Record 41 of Set 6 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=asau
# Processing Record 42 of Set 6 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=alta+floresta
# Processing Record 43 of Set 6 | maracai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=maracai
# Processing Record 44 of Set 6 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ostrovnoy
# Processing Record 45 of Set 6 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=coquimbo
# Processing Record 46 of Set 6 | xocotla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=xocotla
# Processing Record 47 of Set 6 | aranos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=aranos
# Processing Record 48 of Set 6 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 6 | bullhead city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=bullhead+city
# Processing Record 50 of Set 6 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=cayenne
# Processing Record 1 of Set 7 | otacilio costa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=otacilio+costa
# Processing Record 2 of Set 7 | mlowo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=mlowo
# Processing Record 3 of Set 7 | evanton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=evanton
# Processing Record 4 of Set 7 | barbar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=barbar
# City not found. Skipping...
# Processing Record 5 of Set 7 | luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=luanda
# Processing Record 6 of Set 7 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=port+macquarie
# Processing Record 7 of Set 7 | maua
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=skjervoy
# Processing Record 46 of Set 14 | cauquenes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=cauquenes
# Processing Record 47 of Set 14 | klyuchi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=klyuchi
# Processing Record 48 of Set 14 | lyuban
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=lyuban
# Processing Record 49 of Set 14 | san jose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=san+jose
# Processing Record 50 of Set 14 | port pirie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=port+pirie
# Processing Record 1 of Set 15 | tyup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=tyup
# Processing Record 2 of Set 15 | mantua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=mantua
# Processing Record 3 of Set 15 | guaira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=guaira
# Processing Record 4 of Set 15 | ingham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ingham
# Processing Record 5 of Set 15 | upata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=upata
# Processing Record 6 of Set 15 | yaguajay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=yaguajay
# Processing Record 7 of Set 15 | satitoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=satitoa
# City not found. Skipping...
# Processing Record 8 of Set 15 | ust-omchug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ust-omchug
# Processing Record 9 of Set 15 | gunnaur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=gunnaur
# Processing Record 10 of Set 15 | bay city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=bay+city
# Processing Record 11 of Set 15 | kearney
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kearney
# Processing Record 12 of Set 15 | merauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=merauke
# Processing Record 13 of Set 15 | nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=nishihara
# Processing Record 14 of Set 15 | mendi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=mendi
# Processing Record 15 of Set 15 | abbeville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=abbeville
# Processing Record 16 of Set 15 | huilong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=huilong
# Processing Record 17 of Set 15 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ahipara
# Processing Record 18 of Set 15 | pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=pochutla
# Processing Record 19 of Set 15 | mrirt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=mrirt
# City not found. Skipping...
# Processing Record 20 of Set 15 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=tautira
# Processing Record 21 of Set 15 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=atar
# Processing Record 22 of Set 15 | bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=bambanglipuro
# Processing Record 23 of Set 15 | kantang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kantang
# Processing Record 24 of Set 15 | safety harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=safety+harbor
# Processing Record 25 of Set 15 | gemena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=gemena
# Processing Record 26 of Set 15 | buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=buraydah
# Processing Record 27 of Set 15 | sorvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=sorvag
# City not found. Skipping...
# Processing Record 28 of Set 15 | hurricane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=hurricane
# Processing Record 29 of Set 15 | moosomin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=moosomin
# Processing Record 30 of Set 15 | bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=bowen
# Processing Record 31 of Set 15 | malkara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=malkara
# Processing Record 32 of Set 15 | korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=korla
# Processing Record 33 of Set 15 | conde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=conde
# Processing Record 34 of Set 15 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=broken+hill
# Processing Record 35 of Set 15 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=tilichiki
# Processing Record 36 of Set 15 | haibowan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=haibowan
# City not found. Skipping...
# Processing Record 37 of Set 15 | oyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=oyama
# Processing Record 38 of Set 15 | agirish
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=agirish
# Processing Record 39 of Set 15 | atyuryevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=atyuryevo
# City not found. Skipping...
# Processing Record 40 of Set 15 | samana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=samana
# Processing Record 41 of Set 15 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=husavik
# Processing Record 42 of Set 15 | grimshaw
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=grimshaw
# Processing Record 43 of Set 15 | xichang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=xichang
# Processing Record 44 of Set 15 | abha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=abha
# Processing Record 45 of Set 15 | okato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=okato
# Processing Record 46 of Set 15 | magadan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=magadan
# Processing Record 47 of Set 15 | ionia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ionia
# Processing Record 48 of Set 15 | ilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ilo
# Processing Record 49 of Set 15 | mazamari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=mazamari
# Processing Record 50 of Set 15 | huntsville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=huntsville
# Processing Record 1 of Set 16 | duma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=duma
# Processing Record 2 of Set 16 | inuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=inuvik
# Processing Record 3 of Set 16 | toliary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=toliary
# City not found. Skipping...
# Processing Record 4 of Set 16 | muisne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=muisne
# Processing Record 5 of Set 16 | ileza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ileza
# Processing Record 6 of Set 16 | honningsvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=honningsvag
# Processing Record 7 of Set 16 | spring valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=spring+valley
# Processing Record 8 of Set 16 | ippy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ippy
# Processing Record 9 of Set 16 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=raudeberg
# Processing Record 10 of Set 16 | galesong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=galesong
# Processing Record 11 of Set 16 | banmo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=banmo
# City not found. Skipping...
# Processing Record 12 of Set 16 | kainantu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kainantu
# Processing Record 13 of Set 16 | pombal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=pombal
# Processing Record 14 of Set 16 | marabba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=marabba
# Processing Record 15 of Set 16 | scunthorpe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=scunthorpe
# Processing Record 16 of Set 16 | vredendal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=vredendal
# Processing Record 17 of Set 16 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=broome
# Processing Record 18 of Set 16 | serra talhada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=serra+talhada
# Processing Record 19 of Set 16 | great falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=great+falls
# Processing Record 20 of Set 16 | choya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=choya
# Processing Record 21 of Set 16 | launceston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=launceston
# Processing Record 22 of Set 16 | yelizovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=yelizovo
# Processing Record 23 of Set 16 | ranfurly
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ranfurly
# Processing Record 24 of Set 16 | guamal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=guamal
# Processing Record 25 of Set 16 | requena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=requena
# Processing Record 26 of Set 16 | sarangani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=sarangani
# Processing Record 27 of Set 16 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=qaqortoq
# Processing Record 28 of Set 16 | tokur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=tokur
# Processing Record 29 of Set 16 | koumac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=koumac
# Processing Record 30 of Set 16 | woodward
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=woodward
# Processing Record 31 of Set 16 | yomitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=yomitan
# City not found. Skipping...
# Processing Record 32 of Set 16 | zhumadian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=zhumadian
# Processing Record 33 of Set 16 | neiafu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=neiafu
# Processing Record 34 of Set 16 | monrovia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=monrovia
# Processing Record 35 of Set 16 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=labuhan
# Processing Record 36 of Set 16 | cockburn harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=cockburn+harbour
# City not found. Skipping...
# Processing Record 37 of Set 16 | watsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=watsa
# Processing Record 38 of Set 16 | ca mau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=ca+mau
# Processing Record 39 of Set 16 | dzhusaly
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 16 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=paamiut
# Processing Record 41 of Set 16 | nemyriv
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=nemyriv
# Processing Record 42 of Set 16 | junin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=junin
# Processing Record 43 of Set 16 | bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=bonavista
# Processing Record 44 of Set 16 | chingirlau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=chingirlau
# Processing Record 45 of Set 16 | naryan-mar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=naryan-mar
# Processing Record 46 of Set 16 | tabou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=tabou
# Processing Record 47 of Set 16 | kokoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9db4f4a365c230710dba151dfd61f705&q=kokoda
# Done
# ----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
out_put_data = "weather_database/WeatherPy_Database.csv"
city_data_df.to_csv(out_put_data, index_label = "City ID")

# %%
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ushuaia      AR -54.8000  -68.3000     49.66        34          40
# 1           Kumo      NG  10.0447   11.2122     74.89        83         100
# 2        Camacha      PT  33.0833  -16.3333     69.22        60          20
# 3      Cape Town      ZA -33.9258   18.4232     61.88        84          40
# 4    Tuktoyaktuk      CA  69.4541 -133.0374     32.00        93          90
# ..           ...     ...      ...       ...       ...       ...         ...
# 726    Bonavista      CA  48.6499  -53.1147     71.60        89          20
# 727   Chingirlau      KZ  51.0950   54.0814     61.47        29         100
# 728   Naryan-Mar      RU  67.6713   53.0870     40.21        91         100
# 729        Tabou      CI   4.4230   -7.3528     78.01        86          19
# 730       Kokoda      PG  -8.8785  147.7407     71.37        95          91
#
#      Wind Speed Current Description
# 0         20.71    scattered clouds
# 1          4.81       moderate rain
# 2         11.50          few clouds
# 3          1.01    scattered clouds
# 4          0.00          light snow
# ..          ...                 ...
# 726       17.65          few clouds
# 727       17.90       moderate rain
# 728        8.61     overcast clouds
# 729        6.44          few clouds
# 730        0.45     overcast clouds
#
# [731 rows x 9 columns]
