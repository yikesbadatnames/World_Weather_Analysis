# %%
#importing dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
requests.__version__
from config import weather_api_key
from datetime import datetime

# %%
# creating a list of 200 lats and longs 
lats = np.random.uniform(-90.000,90.000, size = 2000)
lngs = np.random.uniform(-180.000, 180.000, size = 2000)
lats_lngs = zip(lats,lngs)
lats_lngs

# %%
# making url 
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# adding lats_lngs zip to a list
coordinates = list(lats_lngs)
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

# %%
cities
# Out:
# ['hilo',
#  'maues',
#  'spolaita',
#  'camana',
#  'ushuaia',
#  'dikson',
#  'carnarvon',
#  'nioro',
#  'fairbanks',
#  'agirish',
#  'tezu',
#  'albany',
#  'skagastrond',
#  'kampot',
#  'airai',
#  'champerico',
#  'kaitangata',
#  'mount darwin',
#  'bredasdorp',
#  'mrirt',
#  'bethel',
#  'hobart',
#  'ponta do sol',
#  'bonthe',
#  'chokurdakh',
#  'tumalaytay',
#  'kapaa',
#  'altay',
#  'mao',
#  'longyearbyen',
#  'mataura',
#  'castro',
#  'gejiu',
#  'khonuu',
#  'tiksi',
#  'busselton',
#  'vila velha',
#  'masjed-e soleyman',
#  'khatanga',
#  'honiara',
#  'codrington',
#  'barrow',
#  'bluff',
#  'at-bashi',
#  'hithadhoo',
#  'shipitsyno',
#  'mahebourg',
#  'pemberton',
#  'yellowknife',
#  'ciudad bolivar',
#  'torbay',
#  'bartica',
#  'port alfred',
#  'avarua',
#  'marawi',
#  'rikitea',
#  'taolanaro',
#  'beyneu',
#  'georgetown',
#  'bambous virieux',
#  'praya',
#  'puerto ayora',
#  'afsin',
#  'nizhneyansk',
#  'upernavik',
#  'punta arenas',
#  'port elizabeth',
#  'serenje',
#  'hastings',
#  'victoria',
#  'lorengau',
#  'kresttsy',
#  'hermanus',
#  'saint-philippe',
#  'watrous',
#  'torquay',
#  'neuquen',
#  'nikolskoye',
#  'flinders',
#  'bosobolo',
#  'lazaro cardenas',
#  'visnes',
#  'vao',
#  'illoqqortoormiut',
#  'severo-kurilsk',
#  'satitoa',
#  'jamestown',
#  'tuktoyaktuk',
#  'kodiak',
#  'san jose',
#  'khani',
#  'luderitz',
#  'buraydah',
#  'christchurch',
#  'fortuna',
#  'barentsburg',
#  'akyab',
#  'hobyo',
#  'yulara',
#  'lagoa',
#  'dwarka',
#  'conde',
#  'atuona',
#  'zigong',
#  'hay river',
#  'thinadhoo',
#  'abeche',
#  'arlit',
#  'pangnirtung',
#  'chuy',
#  'nome',
#  'clyde river',
#  'east london',
#  'villiers',
#  'sobolevo',
#  'butaritari',
#  'banda aceh',
#  'dingle',
#  'paamiut',
#  'lakatoro',
#  'tukrah',
#  'cayenne',
#  'mys shmidta',
#  'haines junction',
#  'kulhudhuffushi',
#  'beringovskiy',
#  'hovd',
#  'gouyave',
#  'ugoofaaru',
#  'cape town',
#  'broome',
#  'oranjemund',
#  'bintulu',
#  'yaan',
#  'araouane',
#  'new norfolk',
#  'belushya guba',
#  'haibowan',
#  'firovo',
#  'goderich',
#  'beatrice',
#  'balabac',
#  'talnakh',
#  'berea',
#  'cidreira',
#  'bandarbeyla',
#  'chimbote',
#  'smithers',
#  'urumqi',
#  'kamaishi',
#  'port hedland',
#  'iqaluit',
#  'manoel urbano',
#  'sharon',
#  'bonavista',
#  'warrnambool',
#  'piacabucu',
#  'henties bay',
#  'khuzhir',
#  'sindor',
#  'saint-francois',
#  'touros',
#  'narsaq',
#  'vaini',
#  'cherskiy',
#  'ancud',
#  'saskylakh',
#  'bosaso',
#  'lahij',
#  'yatou',
#  'padang',
#  'geraldton',
#  'borogontsy',
#  'mana',
#  'acarau',
#  'makakilo city',
#  'yar-sale',
#  'coolum beach',
#  'deer lake',
#  'cabo san lucas',
#  'skjervoy',
#  'tumannyy',
#  'saint george',
#  'matara',
#  'constitucion',
#  'ahipara',
#  'antofagasta',
#  'necochea',
#  'sitka',
#  'arica',
#  'north myrtle beach',
#  'nabire',
#  'kidal',
#  'san policarpo',
#  'halalo',
#  'tsihombe',
#  'laguna',
#  'qaanaaq',
#  'pisco',
#  'lyngseidet',
#  'coquimbo',
#  'port hawkesbury',
#  'noumea',
#  'guerrero negro',
#  'kruisfontein',
#  'grand gaube',
#  'nurlat',
#  'saint-georges',
#  'ormara',
#  'irituia',
#  'cabedelo',
#  'ganzhou',
#  'herat',
#  'tiznit',
#  'nuuk',
#  'hasaki',
#  'west wendover',
#  'vaitupu',
#  'barra',
#  'provideniya',
#  'peravurani',
#  'hualmay',
#  'domna',
#  'souillac',
#  'hammerfest',
#  'kavieng',
#  'amderma',
#  'chongwe',
#  'sabla',
#  'da nang',
#  'beidao',
#  'margate',
#  'lavrentiya',
#  'chase',
#  'kelvington',
#  'asau',
#  'thompson',
#  'inuvik',
#  'santa eulalia del rio',
#  'ilhabela',
#  'vanavara',
#  'kabo',
#  'buala',
#  'luanda',
#  'phalodi',
#  'presidencia roque saenz pena',
#  'hirara',
#  'warrington',
#  'bubaque',
#  'fort saint john',
#  'dunedin',
#  'wad rawah',
#  'hamilton',
#  'arraial do cabo',
#  'tari',
#  'rincon',
#  'hopelchen',
#  'kpandae',
#  'mar del plata',
#  'lazi',
#  'isangel',
#  'leningradskiy',
#  'ypsonas',
#  'saleaula',
#  'ludvika',
#  'mackay',
#  'lithgow',
#  'deputatskiy',
#  'srednekolymsk',
#  'sangar',
#  'san vicente',
#  'wanning',
#  'panaba',
#  'dipkarpaz',
#  'cheuskiny',
#  'naze',
#  'zaraza',
#  'alamosa',
#  'korla',
#  'bulanash',
#  'lata',
#  'zhezkazgan',
#  'volchikha',
#  'san patricio',
#  'spring valley',
#  'shimoda',
#  'yaypan',
#  'matay',
#  'faanui',
#  'chapais',
#  'luwuk',
#  'half moon bay',
#  'labutta',
#  'katsuura',
#  'jinchang',
#  'acapulco',
#  'alofi',
#  'san luis',
#  'dese',
#  'dzhusaly',
#  'inongo',
#  'jabiru',
#  'port-gentil',
#  'hokitika',
#  'waseca',
#  'erenhot',
#  'goundam',
#  'luau',
#  'ulaangom',
#  'upata',
#  'soke',
#  'samalaeulu',
#  'yondo',
#  'goure',
#  'maldonado',
#  'brae',
#  'san ramon',
#  'ostrovnoy',
#  'doctor pedro p. pena',
#  'cap malheureux',
#  'guymon',
#  'diamantino',
#  'lebu',
#  'jalingo',
#  'byron bay',
#  'rovaniemi',
#  'verkh-usugli',
#  'samusu',
#  'bukachacha',
#  'havre-saint-pierre',
#  'keningau',
#  'norman wells',
#  'tsabong',
#  'tonota',
#  'lima',
#  'port lincoln',
#  'gushikawa',
#  'sinnamary',
#  'dzerzhinsk',
#  'saint-pierre',
#  'havre',
#  'nanortalik',
#  'galle',
#  'huarmey',
#  'fujin',
#  'lufilufi',
#  'newport',
#  'kaeo',
#  'bilibino',
#  'takayama',
#  'sistranda',
#  'along',
#  'ixtapa',
#  'louisbourg',
#  'bathsheba',
#  'sao joao da barra',
#  'bulawayo',
#  'bordighera',
#  'varkkallai',
#  'akdepe',
#  'ruidoso',
#  'palana',
#  'oyama',
#  'sindand',
#  'tuatapere',
#  'taloqan',
#  'talagang',
#  'askiz',
#  'key largo',
#  'binga',
#  'ribeira grande',
#  'sola',
#  'kahului',
#  'mayya',
#  'filingue',
#  'muros',
#  'lasa',
#  'mirnyy',
#  'berlevag',
#  'san antonio',
#  'phan rang',
#  'skalistyy',
#  'tasiilaq',
#  'rundu',
#  'yakima',
#  'winchester',
#  'eskasem',
#  'kjollefjord',
#  'grand river south east',
#  'bahir dar',
#  'coxim',
#  'san andres',
#  'hambantota',
#  'faya',
#  'suntar',
#  'zhigansk',
#  'naftah',
#  'staryy nadym',
#  'inhambane',
#  'mount gambier',
#  'burica',
#  'sioux lookout',
#  'dvinskoy',
#  'umm kaddadah',
#  'syedove',
#  'huilong',
#  'la ronge',
#  'port macquarie',
#  'plettenberg bay',
#  'freeport',
#  'locri',
#  'carlow',
#  'salinopolis',
#  'homer',
#  'lompoc',
#  'palmer',
#  'pine bluff',
#  'ca mau',
#  'rocha',
#  'canmore',
#  'riachao das neves',
#  'kaduqli',
#  'kiruna',
#  'caravelas',
#  'comodoro rivadavia',
#  'tarko-sale',
#  'zhangjiakou',
#  'panguna',
#  'bajil',
#  'abha',
#  'union',
#  'mogadishu',
#  'tabiauea',
#  'toliary',
#  'maridi',
#  'faridabad',
#  'batemans bay',
#  'leninskoye',
#  'shima',
#  'gamba',
#  'bali chak',
#  'horsham',
#  'japura',
#  'tura',
#  'esperance',
#  'ballina',
#  'behbahan',
#  'coihaique',
#  'okegawa',
#  'port hardy',
#  'vardo',
#  'grindavik',
#  'kendari',
#  'college',
#  'manokwari',
#  'okha',
#  'price',
#  'itoman',
#  'vila franca do campo',
#  'dongsheng',
#  'labuhan',
#  'northam',
#  'saint-augustin',
#  'asayita',
#  'pacific grove',
#  'vanimo',
#  'baykit',
#  'chagda',
#  'hervey bay',
#  'merauke',
#  'harper',
#  'salalah',
#  'sankt leon-rot',
#  'kabelvag',
#  'bull savanna',
#  'hofn',
#  'irara',
#  'bestobe',
#  'coffs harbour',
#  'panjab',
#  'yerbogachen',
#  'sabya',
#  'sumter',
#  'colares',
#  'miranorte',
#  'koson',
#  'taoudenni',
#  'ambon',
#  'narragansett',
#  'sao filipe',
#  'aklavik',
#  'zholymbet',
#  'temaraia',
#  'fort nelson',
#  'miandrivazo',
#  'biak',
#  'jalu',
#  'kijang',
#  'mandurah',
#  'picayune',
#  'volcan',
#  'karamay',
#  'turbat',
#  'pangkalanbuun',
#  'praia da vitoria',
#  'coahuayana',
#  'chor',
#  'praia',
#  'klaksvik',
#  'altamont',
#  'nizhniy tsasuchey',
#  'san cristobal',
#  'el retorno',
#  'manicore',
#  'jinji',
#  'chumikan',
#  'tharrawaddy',
#  'na wa',
#  'phangnga',
#  'senj',
#  'valday',
#  'shubarkuduk',
#  'lhokseumawe',
#  'kloulklubed',
#  'cockburn town',
#  'nemuro',
#  'dolores',
#  'manakara',
#  'kamenka',
#  'baruun-urt',
#  'pogar',
#  'luganville',
#  'omboue',
#  'kupino',
#  'banmo',
#  'bracebridge',
#  'khor',
#  'nuevitas',
#  'nara',
#  'quelimane',
#  'cloquet',
#  'chateaubelair',
#  'amberley',
#  'zlate moravce',
#  'noyabrsk',
#  'morrope',
#  'belmonte',
#  'longyan',
#  'sentyabrskiy',
#  'preobrazheniye',
#  'bulgan',
#  'stornoway',
#  'stranda',
#  'lukovetskiy',
#  'batouri',
#  'okhotsk',
#  'avera',
#  'sakaraha',
#  'skibbereen',
#  'tandil',
#  'taraza',
#  'parabel',
#  'hami',
#  'vallenar',
#  'axim',
#  'puerto ayacucho',
#  'bolungarvik',
#  'hurghada',
#  'matamoros',
#  'kimbe',
#  'muyezerskiy',
#  'laramie',
#  'hurricane',
#  'gus-zheleznyy',
#  'amapa',
#  'tateyama',
#  'chara',
#  'vitimskiy',
#  'russell',
#  'mogok',
#  'umuahia',
#  'kimberley',
#  'wajima',
#  'qaqortoq',
#  'neon karlovasion',
#  'qandala',
#  'plouzane',
#  'olafsvik',
#  'norsup',
#  'erzin',
#  'meiganga',
#  'masoko',
#  'sinkat',
#  'saint anthony',
#  'chuguyevka',
#  'ilulissat',
#  'cozumel',
#  'namibe',
#  'eregli',
#  'quatre cocos',
#  'silver city',
#  'port blair',
#  'muskogee',
#  'pevek',
#  'north platte',
#  'tidore',
#  'havoysund',
#  'burmakino',
#  'miranda',
#  'coleraine',
#  'sidi qasim',
#  'puri',
#  'marsh harbour',
#  'tilichiki',
#  'kattivakkam',
#  'vuktyl',
#  'juye',
#  'bengkulu',
#  'kropotkin',
#  'basco',
#  'menongue',
#  'smolenka',
#  'asosa',
#  'bani walid',
#  'palabuhanratu',
#  'broken hill',
#  'vostok',
#  'kangaatsiaq',
#  'play cu',
#  'auki',
#  'iraucuba',
#  'samarai',
#  'kasane',
#  'ozinki',
#  'nosy varika',
#  'mecca',
#  'saint-joseph',
#  'cooma',
#  'eldorado',
#  'leh',
#  'bur gabo',
#  'turukhansk',
#  'geresk',
#  'cochrane',
#  'abong mbang',
#  'koumac',
#  'mujiayingzi',
#  'cantaura',
#  'taltal',
#  'zhanatas',
#  'ketchikan',
#  'lalomanu',
#  'nilagiri',
#  'jabinyanah',
#  'namatanai',
#  'gorontalo',
#  'chaykovskiy',
#  'aban',
#  'zaqatala',
#  'abrau-dyurso',
#  'mareeba',
#  'vrangel',
#  'marca',
#  'bibiani',
#  'mendeleyevsk',
#  'vestmannaeyjar',
#  'nantucket',
#  'purpe',
#  'karamea',
#  'puerto madryn',
#  'kazalinsk',
#  'sapa',
#  'los llanos de aridane',
#  'yomitan',
#  'tambo',
#  'hatta',
#  'kenai',
#  'nhulunbuy',
#  'cangucu',
#  'lubango',
#  'amga',
#  'nyurba',
#  'alta floresta',
#  'nhamunda',
#  'ust-maya',
#  'rawson',
#  'estrela',
#  'sambava',
#  'sept-iles',
#  'nkowakowa',
#  'gizo',
#  'sigli',
#  'wanaka',
#  'yei',
#  'sao jose da coroa grande',
#  'ruatoria',
#  'lolua',
#  'zhangye',
#  'seoul',
#  'aksu',
#  'moose factory',
#  'sur',
#  'elat',
#  'strezhevoy',
#  'klichka',
#  'rudraprayag',
#  'peleduy',
#  'aitape',
#  'boa vista',
#  'tsiroanomandidy',
#  'sisimiut',
#  'manggar',
#  'sol-iletsk',
#  'zabid',
#  'pospelikha',
#  'amuntai',
#  'carauari',
#  'paredon',
#  'pitkyaranta',
#  'muravlenko',
#  'nishihara',
#  'turkan',
#  'sabha',
#  'ambovombe',
#  'gurlan',
#  'bima',
#  'tongliao',
#  'egvekinot',
#  'saldanha',
#  'waterloo',
#  'montepuez',
#  'kuche',
#  'darhan',
#  'pampa',
#  'dijon',
#  'maple creek',
#  'ebolowa',
#  'tunduru',
#  'aksha',
#  'itupiranga',
#  'sorland',
#  'tambopata',
#  'litovel',
#  'porto nacional',
#  'motzorongo',
#  'imeni zhelyabova']

# %%
# loop to get weather information
city_data = []
#printing begining of loop
print("Beginning Data Retrieval")
print("------------------------")
#creating counters
record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(city_url) 
    record_count += 1

    try:
        req = requests.get(city_url)
        city_weather = req.json()
        #data needed
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_cloud = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_data.append({"City" : city.title(),
                          "Country" : city_country,
                          "Lat" :  city_lat,
                          "Lng" : city_lng,
                          "Max Temp" : city_max_temp,
                          "Humidity" : city_humidity,
                          "Cloudiness" : city_cloud,
                          "Wind Speed" : city_wind,
                          "Current Description" : city_desc})
    except:
        print("City not found. Skipping...")
        pass
print("Done")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=hilo
# Processing Record 2 of Set 1 | maues
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=maues
# Processing Record 3 of Set 1 | spolaita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=spolaita
# Processing Record 4 of Set 1 | camana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=camana
# Processing Record 5 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=ushuaia
# Processing Record 6 of Set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=dikson
# Processing Record 7 of Set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=carnarvon
# Processing Record 8 of Set 1 | nioro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=nioro
# Processing Record 9 of Set 1 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=fairbanks
# Processing Record 10 of Set 1 | agirish
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=agirish
# Processing Record 11 of Set 1 | tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=tezu
# Processing Record 12 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=albany
# Processing Record 13 of Set 1 | skagastrond
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=skagastrond
# City not found. Skipping...
# Processing Record 14 of Set 1 | kampot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=kampot
# Processing Record 15 of Set 1 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=airai
# Processing Record 16 of Set 1 | champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=champerico
# Processing Record 17 of Set 1 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=kaitangata
# Processing Record 18 of Set 1 | mount darwin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=mount+darwin
# Processing Record 19 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=bredasdorp
# Processing Record 20 of Set 1 | mrirt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=mrirt
# City not found. Skipping...
# Processing Record 21 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=bethel
# Processing Record 22 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=hobart
# Processing Record 23 of Set 1 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=ponta+do+sol
# Processing Record 24 of Set 1 | bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=bonthe
# Processing Record 25 of Set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=chokurdakh
# Processing Record 26 of Set 1 | tumalaytay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=tumalaytay
# Processing Record 27 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=kapaa
# Processing Record 28 of Set 1 | altay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=altay
# Processing Record 29 of Set 1 | mao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=mao
# Processing Record 30 of Set 1 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=longyearbyen
# Processing Record 31 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=mataura
# Processing Record 32 of Set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=castro
# City not found. Skipping...
# Processing Record 33 of Set 1 | gejiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=gejiu
# Processing Record 34 of Set 1 | khonuu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=khonuu
# City not found. Skipping...
# Processing Record 35 of Set 1 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=tiksi
# Processing Record 36 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=busselton
# Processing Record 37 of Set 1 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=vila+velha
# Processing Record 38 of Set 1 | masjed-e soleyman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=masjed-e+soleyman
# City not found. Skipping...
# Processing Record 39 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=khatanga
# Processing Record 40 of Set 1 | honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=honiara
# Processing Record 41 of Set 1 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=codrington
# Processing Record 42 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=barrow
# Processing Record 43 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=bluff
# Processing Record 44 of Set 1 | at-bashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=at-bashi
# Processing Record 45 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=hithadhoo
# Processing Record 46 of Set 1 | shipitsyno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=shipitsyno
# Processing Record 47 of Set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=mahebourg
# Processing Record 48 of Set 1 | pemberton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=pemberton
# Processing Record 49 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=yellowknife
# Processing Record 50 of Set 1 | ciudad bolivar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=ciudad+bolivar
# Processing Record 1 of Set 2 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=torbay
# Processing Record 2 of Set 2 | bartica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=bartica
# Processing Record 3 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=port+alfred
# Processing Record 4 of Set 2 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=avarua
# Processing Record 5 of Set 2 | marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=marawi
# Processing Record 6 of Set 2 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=rikitea
# Processing Record 7 of Set 2 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 2 | beyneu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=beyneu
# Processing Record 9 of Set 2 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=georgetown
# Processing Record 10 of Set 2 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=bambous+virieux
# Processing Record 11 of Set 2 | praya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=praya
# Processing Record 12 of Set 2 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=puerto+ayora
# City not found. Skipping...
# Processing Record 13 of Set 2 | afsin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=afsin
# Processing Record 14 of Set 2 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 2 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=upernavik
# Processing Record 16 of Set 2 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=punta+arenas
# Processing Record 17 of Set 2 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=port+elizabeth
# Processing Record 18 of Set 2 | serenje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=serenje
# Processing Record 19 of Set 2 | hastings
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=hastings
# Processing Record 20 of Set 2 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=victoria
# Processing Record 21 of Set 2 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=lorengau
# Processing Record 22 of Set 2 | kresttsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=kresttsy
# Processing Record 23 of Set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=hermanus
# Processing Record 24 of Set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=saint-philippe
# Processing Record 25 of Set 2 | watrous
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=watrous
# Processing Record 26 of Set 2 | torquay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=torquay
# Processing Record 27 of Set 2 | neuquen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=neuquen
# Processing Record 28 of Set 2 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=nikolskoye
# Processing Record 29 of Set 2 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=flinders
# Processing Record 30 of Set 2 | bosobolo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8adb2b19db7668628620960b6a4bfd52&q=bosobolo

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
out_put_data = "weather_database/WeatherPy_Database.csv"
city_data_df.to_csv(out_put_data, index_label = "City ID")

# %%
city_data_df
